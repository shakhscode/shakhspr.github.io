# %%
#import required libraries
import pandas as pd

# %%
#read the processed dataset
df=pd.read_csv('processedData1.csv')
df
# Out:
#               gT            sId          rId         sAcc        rAcc  \
# 0      N-RegDep         PN_Ret2  PN_EU_0_261        RAcc2  EUAcc0_261
# 1      N_Reg_RC     PN_EU_1_502     operator   EUAcc1_502          A0
# 2      N-RegDep         PN_Ret2  PN_EU_1_362        RAcc2  EUAcc1_362
# 3      N_Reg_RC      PN_EU_1_26     operator    EUAcc1_26          A0
# 4      N_Reg_RC      PN_EU_1_18     operator    EUAcc1_18          A0
# ...          ...            ...          ...          ...         ...
# 54217  N_Reg_RC     PN_EU_0_116     operator   EUAcc0_116          A0
# 54218  N_Reg_RC    PN_EU_0_1256     operator  EUAcc0_1256          A0
# 54219  N-RegDep         PN_Ret6  PN_EU_1_143        RAcc6  EUAcc1_143
# 54220  N-RegC2C     PN_EU_1_197   PN_EU_2_85   EUAcc1_197   EUAcc2_85
# 54221  N-RegDep         PN_Ret5  PN_EU_1_360        RAcc5  EUAcc1_360
#
#        TranAmount TranType TranStatus    sBalbefore     sBalAfter  \
# ...
