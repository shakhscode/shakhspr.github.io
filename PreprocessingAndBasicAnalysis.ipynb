# %%
#import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize']=(20,10)

# %%
#read the csv dataset
df=pd.read_csv('fraudDetectionSamples.csv')
df.head()
# Out:
#           gT           sId          rId        sAcc        rAcc  TranAmount  \
# 0  N-RegDep        PN_Ret2  PN_EU_0_261       RAcc2  EUAcc0_261   131926.49
# 1  N_Reg_RC    PN_EU_1_502     operator  EUAcc1_502          A0     2054.46
# 2  N-RegDep        PN_Ret2  PN_EU_1_362       RAcc2  EUAcc1_362   182548.74
# 3  N_Reg_RC     PN_EU_1_26     operator   EUAcc1_26          A0     5507.28
# 4  N_Reg_RC     PN_EU_1_18     operator   EUAcc1_18          A0     2102.60
#
#   TranType TranStatus    sBalbefore     sBalAfter  ...  sf4               sTD  \
# 0       Dt         SU  1.000000e+09  9.998681e+08  ...  NaN  1/6/2011 0:11:22
# 1     ArRC         SU  1.000000e+08  9.999795e+07  ...  NaN   1/6/2011 0:16:8
# 2       Dt         SU  9.998681e+08  9.996855e+08  ...  NaN  1/6/2011 0:36:47
# 3     ArRC         SU  1.000000e+08  9.999449e+07  ...  NaN  1/6/2011 0:36:59
# 4     ArRC         SU  1.000000e+08  9.999790e+07  ...  NaN   1/6/2011 1:1:26
#
#                 rTD      sAccID  ef1  ef2   NoDescription            TranTS  \
# 0  1/6/2011 0:11:22       RAcc2  NaN  NaN  Dp201161.01111  1/6/2011 0:11:22
# 1   1/6/2011 0:16:8  EUAcc1_502  NaN  NaN  Rc201161.01616   1/6/2011 0:16:8
# 2  1/6/2011 0:36:47       RAcc2  NaN  NaN  Dp201161.03636  1/6/2011 0:36:47
# 3  1/6/2011 0:36:59   EUAcc1_26  NaN  NaN  Rc201161.03636  1/6/2011 0:36:59
# 4   1/6/2011 1:1:26   EUAcc1_18  NaN  NaN    Rc201161.111   1/6/2011 1:1:26
#
#   sType     rType
# 0   RET        EU
# 1    EU  operator
# 2   RET        EU
# 3    EU  operator
# 4    EU  operator
#
# [5 rows x 25 columns]

# %%
#Check for missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54222 entries, 0 to 54221
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gT             54222 non-null  object
#  1   sId            54222 non-null  object
#  2   rId            54222 non-null  object
#  3   sAcc           54222 non-null  object
#  4   rAcc           54222 non-null  object
#  5   TranAmount     54222 non-null  float64
#  6   TranType       54222 non-null  object
#  7   TranStatus     54222 non-null  object
#  8   sBalbefore     54222 non-null  float64
#  9   sBalAfter      54222 non-null  float64
#  10  rBalBefore     54222 non-null  float64
#  11  rBalAfter      54222 non-null  float64
#  12  sf1            54222 non-null  bool
#  13  sf2            54222 non-null  bool
#  14  sf3            0 non-null      float64
#  15  sf4            0 non-null      float64
#  16  sTD            54222 non-null  object
#  17  rTD            54222 non-null  object
#  18  sAccID         54222 non-null  object
#  19  ef1            0 non-null      float64
#  20  ef2            0 non-null      float64
#  21  NoDescription  54222 non-null  object
#  22  TranTS         54222 non-null  object
#  23  sType          54222 non-null  object
#  24  rType          54222 non-null  object
# dtypes: bool(2), float64(9), object(14)
# memory usage: 9.6+ MB

# %%
#it is observed that service field 3,4 and empty fields 1 and 2 has no values.
#Except that there are no missing values

#column 3 and 18 have same values

#So drop the empty columns and simillar columns
columns = ['sf3', 'sf4', 'ef1', 'ef2', 'sAccID','NoDescription']
df.drop(columns, inplace=True, axis=1)
data = df

# %%
#get the new information about the extracted dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54222 entries, 0 to 54221
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   gT          54222 non-null  object
#  1   sId         54222 non-null  object
#  2   rId         54222 non-null  object
#  3   sAcc        54222 non-null  object
#  4   rAcc        54222 non-null  object
#  5   TranAmount  54222 non-null  float64
#  6   TranType    54222 non-null  object
#  7   TranStatus  54222 non-null  object
#  8   sBalbefore  54222 non-null  float64
#  9   sBalAfter   54222 non-null  float64
#  10  rBalBefore  54222 non-null  float64
#  11  rBalAfter   54222 non-null  float64
#  12  sf1         54222 non-null  bool
#  13  sf2         54222 non-null  bool
#  14  sTD         54222 non-null  object
#  15  rTD         54222 non-null  object
#  16  TranTS      54222 non-null  object
#  17  sType       54222 non-null  object
#  18  rType       54222 non-null  object
# dtypes: bool(2), float64(5), object(12)
# memory usage: 7.1+ MB

# %%
#export the file data as a new dataset
data.to_csv('processedData1.csv',index=False)

# %%
df2=np.transpose(data)
df2
# Out:
#                        0                1                 2      \
# gT                 N-RegDep         N_Reg_RC          N-RegDep
# sId                  PN_Ret2      PN_EU_1_502           PN_Ret2
# rId              PN_EU_0_261         operator       PN_EU_1_362
# sAcc                   RAcc2       EUAcc1_502             RAcc2
# rAcc              EUAcc0_261               A0        EUAcc1_362
# TranAmount         131926.49          2054.46         182548.74
# TranType                  Dt             ArRC                Dt
# TranStatus                SU               SU                SU
# sBalbefore      1000000000.0      100000000.0      999868073.51
# sBalAfter       999868073.51      99997945.54      999685524.77
# rBalBefore      100131926.49      99180036.56      100182548.74
# rBalAfter        100000000.0       99177982.1       100000000.0
# sf1                     True             True              True
# sf2                     True             True              True
# sTD         1/6/2011 0:11:22  1/6/2011 0:16:8  1/6/2011 0:36:47
# rTD         1/6/2011 0:11:22  1/6/2011 0:16:8  1/6/2011 0:36:47
# TranTS      1/6/2011 0:11:22  1/6/2011 0:16:8  1/6/2011 0:36:47
# sType                    RET               EU               RET
# rType                     EU         operator                EU
#
#                        3                4                5      \
# gT                 N_Reg_RC         N_Reg_RC         N_Reg_RC
# sId               PN_EU_1_26       PN_EU_1_18      PN_EU_0_786
# rId                 operator         operator         operator
# sAcc               EUAcc1_26        EUAcc1_18       EUAcc0_786
# rAcc                      A0               A0               A0
# TranAmount           5507.28           2102.6          1361.77
# TranType                ArRC             ArRC             ArRC
# TranStatus                SU               SU               SU
# sBalbefore       100000000.0      100000000.0      100000000.0
# sBalAfter        99994492.72       99997897.4      99998638.23
# rBalBefore       99185543.84      99187646.44      99189008.21
# rBalAfter        99180036.56      99185543.84      99187646.44
# sf1                     True             True             True
# sf2                     True             True             True
# sTD         1/6/2011 0:36:59  1/6/2011 1:1:26  1/6/2011 1:5:37
# rTD         1/6/2011 0:36:59  1/6/2011 1:1:26  1/6/2011 1:5:37
# TranTS      1/6/2011 0:36:59  1/6/2011 1:1:26  1/6/2011 1:5:37
# sType                     EU               EU               EU
# rType               operator         operator         operator
#
#                        6                7                 8      \
# gT                 N_Reg_RC         N-RegC2C         N_RegWith
# sId              PN_EU_0_597        PN_EU_2_5       PN_EU_1_131
# rId                 operator      PN_EU_1_121           PN_Ret6
# sAcc              EUAcc0_597         EUAcc2_5        EUAcc1_131
# rAcc                      A0       EUAcc1_121             RAcc6
# TranAmount           6265.82         66197.31         314643.58
# TranType                ArRC              Ind                Wl
# TranStatus                SU               SU                SU
# sBalbefore       100000000.0      100000000.0       100000000.0
# sBalAfter        99993734.18      99933140.72       99682209.98
# rBalBefore       99195274.03     100066197.31      1000316216.8
# rBalAfter        99189008.21      100000000.0      1000000000.0
# sf1                     True             True              True
# sf2                     True             True              True
# sTD         1/6/2011 1:13:20  1/6/2011 1:17:5  1/6/2011 1:27:38
# rTD         1/6/2011 1:13:20  1/6/2011 1:17:5  1/6/2011 1:27:38
# TranTS      1/6/2011 1:13:20  1/6/2011 1:17:5  1/6/2011 1:27:38
# sType                     EU               EU                EU
# rType               operator               EU               RET
#
#                        9      ...              54212               54213  \
# gT                 N-RegDep   ...          N-RegDep            N_Reg_RC
# sId                  PN_Ret3  ...            PN_Ret4        PN_EU_0_1203
# rId               PN_EU_2_86  ...        PN_EU_1_171            operator
# sAcc                   RAcc3  ...              RAcc4         EUAcc0_1203
# rAcc               EUAcc2_86  ...         EUAcc1_171                  A0
# TranAmount         100475.45  ...          104825.17              3193.5
# TranType                  Dt  ...                 Dt                ArRC
# TranStatus                SU  ...                 SU                  SU
# sBalbefore      1000000000.0  ...       847698634.37        100099436.01
# sBalAfter       999899524.55  ...        847593809.2        100096242.51
# rBalBefore      100100475.45  ...       102049092.44        188633716.48
# rBalAfter        100000000.0  ...       101944267.27        188630522.98
# sf1                     True  ...               True                True
# sf2                     True  ...               True                True
# sTD         1/6/2011 1:59:29  ...  30/9/2011 23:7:52  30/9/2011 23:10:38
# rTD         1/6/2011 1:59:29  ...  30/9/2011 23:7:52  30/9/2011 23:10:38
# TranTS      1/6/2011 1:59:29  ...  30/9/2011 23:7:52  30/9/2011 23:10:38
# sType                    RET  ...                RET                  EU
# rType                     EU  ...                 EU            operator
#
#                          54214              54215               54216  \
# gT                   N_Reg_RC           N_Reg_RC            N_Reg_RC
# sId               PN_EU_0_1221        PN_EU_0_414         PN_EU_1_467
# rId                   operator           operator            operator
# sAcc               EUAcc0_1221         EUAcc0_414          EUAcc1_467
# rAcc                        A0                 A0                  A0
# TranAmount              5162.4            1500.92             1738.73
# TranType                  ArRC               ArRC                ArRC
# TranStatus                  SU                 SU                  SU
# sBalbefore        100178686.13        99981519.92        100492639.35
# sBalAfter         100173523.73         99980019.0        100490900.62
# rBalBefore        188638878.88        188640379.8        188642118.53
# rBalAfter         188633716.48       188638878.88         188640379.8
# sf1                       True               True                True
# sf2                       True               True                True
# sTD         30/9/2011 23:13:56  30/9/2011 23:19:4  30/9/2011 23:19:12
# rTD         30/9/2011 23:13:56  30/9/2011 23:19:4  30/9/2011 23:19:12
# TranTS      30/9/2011 23:13:56  30/9/2011 23:19:4  30/9/2011 23:19:12
# sType                       EU                 EU                  EU
# rType                 operator           operator            operator
#
#                         54217               54218               54219  \
# gT                  N_Reg_RC            N_Reg_RC            N-RegDep
# sId               PN_EU_0_116        PN_EU_0_1256             PN_Ret6
# rId                  operator            operator         PN_EU_1_143
# sAcc               EUAcc0_116         EUAcc0_1256               RAcc6
# rAcc                       A0                  A0          EUAcc1_143
# TranAmount              524.7             2106.86           213240.93
# TranType                 ArRC                ArRC                  Dt
# TranStatus                 SU                  SU                  SU
# sBalbefore        99998277.13         99984863.31        878512668.79
# sBalAfter         99997752.43         99982756.45        878299427.86
# rBalBefore       188642643.23        188644750.09        100896931.09
# rBalAfter        188642118.53        188642643.23        100683690.16
# sf1                      True                True                True
# sf2                      True                True                True
# sTD         30/9/2011 23:30:0  30/9/2011 23:32:19  30/9/2011 23:33:23
# rTD         30/9/2011 23:30:0  30/9/2011 23:32:19  30/9/2011 23:33:23
# TranTS      30/9/2011 23:30:0  30/9/2011 23:32:19  30/9/2011 23:33:23
# sType                      EU                  EU                 RET
# rType                operator            operator                  EU
#
#                         54220              54221
# gT                  N-RegC2C           N-RegDep
# sId               PN_EU_1_197            PN_Ret5
# rId                PN_EU_2_85        PN_EU_1_360
# sAcc               EUAcc1_197              RAcc5
# rAcc                EUAcc2_85         EUAcc1_360
# TranAmount          199431.78           87364.76
# TranType                  Ind                 Dt
# TranStatus                 SU                 SU
# sBalbefore        97555773.09       906682058.77
# sBalAfter         97354346.99       906594694.01
# rBalBefore       102173557.07       100331577.35
# rBalAfter        101974125.29       100244212.59
# sf1                      True               True
# sf2                      True               True
# sTD         30/9/2011 23:38:5  30/9/2011 23:49:1
# rTD         30/9/2011 23:38:5  30/9/2011 23:49:1
# TranTS      30/9/2011 23:38:5  30/9/2011 23:49:1
# sType                      EU                RET
# rType                      EU                 EU
#
# [19 rows x 54222 columns]

# %% [markdown]
# # Ananlysis of Categorical Features to know the behaviour of transactions

# %%
cols=['gT','TranStatus','sType','rType']


for i in range(len(cols)):
    plt.subplot(2,2,i+1)
    col=cols[i]
    sns.histplot(df[col])

# %%
for i in range(len(cols)):
    col=cols[i]
    values=df[col].value_counts()
    print("\n",values)
# Out:
#  N_Reg_RC        27901
# N-RegDep        12784
# N-RegC2C         7504
# N_RegWith        3899
# F_bot             731
# F-Mule-With       729
# N_Reg_Merch       442
# F_SevWith         232
# Name: gT, dtype: int64
#
#  SU    54222
# Name: TranStatus, dtype: int64
#
#  EU     41438
# RET    12784
# Name: sType, dtype: int64
#
#  operator    27901
# EU          21019
# RET          4860
# MER           442
# Name: rType, dtype: int64

# %%
# Ananlysis for finding the connections of features in the transactions
